# %%
# Puzzle 1: Import pandas as pd and verify the version.
import pandas as pd
print(pd.__version__)
# Out:
# 2.0.3

# %%
# Puzzle 2: Create a DataFrame from a dictionary.
data = {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35]}
df = pd.DataFrame(data)
df
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
# Puzzle 3: Import a CSV file into a DataFrame.
df_csv = pd.read_csv('file.csv')
print(df_csv.head())
